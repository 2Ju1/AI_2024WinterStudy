# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd /content/drive/MyDrive/study_lab/
# Out:
# /content/drive/MyDrive/study_lab

# %%
# !git config --global user.email '2276242@ewhain.net'
# !git config --global user.name '2ju1'

# %%
# !git add .

# %%
# !git commit -m 'new'
# !git push
# Out:
# [main 4da145c] new
#  4 files changed, 4 insertions(+), 1671 deletions(-)
#  rewrite "Self_Study/\341\204\220\341\205\251\341\206\274\341\204\200\341\205\250\341\204\221\341\205\263\341\204\205\341\205\251\341\204\200\341\205\263\341\204\205\341\205\242\341\204\206\341\205\265\341\206\274/Numpy_1\341\204\214\341\205\256\341\204\216\341\205\241.ipynb" (99%)
#  create mode 100644 "Self_Study/\341\204\220\341\205\251\341\206\274\341\204\200\341\205\250\341\204\221\341\205\263\341\204\205\341\205\251\341\204\200\341\205\263\341\204\205\341\205\242\341\204\206\341\205\265\341\206\274_self/Numpy_1"
#  rewrite for GIt.ipynb (94%)
# Enumerating objects: 16, done.
# Counting objects: 100% (16/16), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (9/9), done.
# Writing objects: 100% (9/9), 14.13 KiB | 535.00 KiB/s, done.
# Total 9 (delta 5), reused 0 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (5/5), completed with 4 local objects.
# remote: This repository moved. Please use the new location:
# remote:   https://github.com/2Ju1/study_lab.git
# To https://github.com/2ju1/study_lab.git
#    e4d5cc5..4da145c  main -> main
