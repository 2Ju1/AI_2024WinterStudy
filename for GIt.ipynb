# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd /content/drive/MyDrive/study_lab/
# Out:
# /content/drive/MyDrive/study_lab

# %%
# !git config --global user.email '2276242@ewhain.net'
# !git config --global user.name '2ju1'

# %%
# !git add .

# %%
# !git commit -m 'new'
# !git push
# Out:
# [main a73cd49] new
#  10 files changed, 2 insertions(+), 2 deletions(-)
#  rewrite "Self_Study/\341\204\220\341\205\251\341\206\274\341\204\200\341\205\250\341\204\221\341\205\263\341\204\205\341\205\251\341\204\200\341\205\263\341\204\205\341\205\242\341\204\206\341\205\265\341\206\274_self/Pytorch.ipynb" (88%)
#  create mode 100644 "Self_Study\\Group8_Pytorch/data/FashionMNIST/raw/t10k-images-idx3-ubyte"
#  create mode 100644 "Self_Study\\Group8_Pytorch/data/FashionMNIST/raw/t10k-images-idx3-ubyte.gz"
#  create mode 100644 "Self_Study\\Group8_Pytorch/data/FashionMNIST/raw/t10k-labels-idx1-ubyte"
#  create mode 100644 "Self_Study\\Group8_Pytorch/data/FashionMNIST/raw/t10k-labels-idx1-ubyte.gz"
#  create mode 100644 "Self_Study\\Group8_Pytorch/data/FashionMNIST/raw/train-images-idx3-ubyte"
#  create mode 100644 "Self_Study\\Group8_Pytorch/data/FashionMNIST/raw/train-images-idx3-ubyte.gz"
#  create mode 100644 "Self_Study\\Group8_Pytorch/data/FashionMNIST/raw/train-labels-idx1-ubyte"
#  create mode 100644 "Self_Study\\Group8_Pytorch/data/FashionMNIST/raw/train-labels-idx1-ubyte.gz"
#  rewrite for GIt.ipynb (72%)
