# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd /content/drive/MyDrive/study_lab/
# Out:
# /content/drive/MyDrive/study_lab

# %%
# !git config --global user.email '2276242@ewhain.net'
# !git config --global user.name '2ju1'

# %%
# !git add .

# %%
# !git commit -m 'new'
# !git push
# Out:
# [main 2d4b2b7] new
#  8 files changed, 229 insertions(+), 2 deletions(-)
#  rewrite for GIt.ipynb (86%)
#  rewrite lab4/Transformer.ipynb (78%)
#  create mode 100644 lab5/Untitled0.ipynb
#  create mode 100644 lab6/PatchTST.ipynb
#  create mode 100644 "lab7/unique_dates_\341\204\202\341\205\241\341\204\211\341\205\263\341\204\203\341\205\241\341\206\250.csv"
#  create mode 100644 "lab7/unique_dates_\341\204\217\341\205\251\341\204\211\341\205\263\341\204\221\341\205\265.csv"
#  create mode 100644 "lab7/unique_dates_\341\204\222\341\205\252\341\206\253\341\204\213\341\205\262\341\206\257.csv"
#  create mode 100644 "lab8_Informer\341\204\217\341\205\251\341\204\203\341\205\263 \341\204\200\341\205\256\341\204\222\341\205\247\341\206\253/Informer.ipynb"
# Enumerating objects: 19, done.
# Counting objects: 100% (19/19), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (12/12), done.
# Writing objects: 100% (15/15), 17.95 KiB | 266.00 KiB/s, done.
# Total 15 (delta 5), reused 0 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (5/5), completed with 3 local objects.
# remote: This repository moved. Please use the new location:
# remote:   https://github.com/2Ju1/study_lab.git
# To https://github.com/2ju1/study_lab.git
#    1d8f0e8..2d4b2b7  main -> main
